# %% [markdown]
# # Outine
# - Data types
# - Why types matter
#     - Operations
#     - Errors
# - Changing a data type
# - Other data types

# %% [markdown]
# ## Data types

# %%
type(1)
# Out:
# int

# %%
type(1.0)
# Out:
# float

# %%
type("Star Wars: The Rise of Skywalker")
# Out:
# str

# %%
type(False)
# Out:
# bool

# %% [markdown]
# ## Why types matter

# %% [markdown]
# ### Operations

# %%
False + True
# Out:
# 1

# %%
type(False + True)
# Out:
# int

# %%
1+2
# Out:
# 3

# %%
"Kale" + "Spinach"
# Out:
# 'KaleSpinach'

# %% [markdown]
# ### Errors

# %%
"Kale"-"Spinach"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-104cedf5b458> in <module>
# ----> 1 "Kale"-"Spinach"
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# ## Changing the data type

# %%
type(15)
# Out:
# int

# %%
float(15)
# Out:
# 15.0

# %%
type(15)
# Out:
# int

# %%
x = 15

# %%
type(x)
# Out:
# int

# %%
y = float(x)

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
str(12)
# Out:
# '12'

# %% [markdown]
# #### Other examples
# - int()
# - bool()

# %%
z = bool(123)
print(z)
# Out:
# True

# %%
n = bool(0)
print(n)
# Out:
# False

# %%
m = bool(-2)
print(m)
# Out:
# True

# %% [markdown]
# ## Other data types
# - Lists
# - Tuples
# - Dictionaries
# - DataFrames
